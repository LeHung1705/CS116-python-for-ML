# %%
import polars as pl

df = pl.scan_parquet("train_data/inference.parquet")
df_2 = pl.scan_parquet("train_data/inference_2.parquet")
df_3 = pl.scan_parquet("train_data/inference_3.parquet")
df_4 = pl.scan_parquet("train_data/inference_4.parquet")

# %%
df = pl.concat([df, df_2, df_3, df_4])

# %%
df.sink_parquet("train_data/inference_final.parquet")
